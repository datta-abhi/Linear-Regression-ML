# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Creating synthetic data using sklearn

# %%
from sklearn.datasets import make_regression

X, y = make_regression(n_samples=100, n_features=2, noise=60, random_state=28)

# Print some samples to verify the ranges
print("X1:", X[:, 0].min(), X[:, 0].max())
print("X2:", X[:, 1].min(), X[:, 1].max())
print("y:", y.min(), y.max())
# Out:
# X1: -2.8774226651402866 3.9966026385775546
# X2: -2.807462041315097 2.272766915940227
# y: -287.32396147127196 280.28961285532785

# %%
df = pd.DataFrame({'feat1':X[:,0],
                  'feat2': X[:,1],
                  'target':y})
df
# Out:
#        feat1     feat2      target
# 0   0.059188  1.514620  115.099758
# 1  -2.877423  0.299694  -29.028436
# 2  -0.039369  2.272767  219.435196
# 3   1.765612 -0.311381   32.236944
# 4   0.658188  0.439482   96.772946
# ..       ...       ...         ...
# 95  0.376421  1.332930  133.229923
# 96 -0.565638 -2.807462 -116.654337
# 97  1.525564 -0.014732   73.186527
# 98 -0.183725  0.176809   -8.608231
# 99 -0.042656  0.046480 -148.438174
#
# [100 rows x 3 columns]

# %%
import plotly.express as px
px.scatter_3d(df,x = 'feat1',y = 'feat2',z = 'target')
# Out:
# <div>                            <div id="125e10f6-cb40-4edb-a8da-12b180a807d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("125e10f6-cb40-4edb-a8da-12b180a807d4")) {                    Plotly.newPlot(                        "125e10f6-cb40-4edb-a8da-12b180a807d4",                        [{"hovertemplate":"feat1=%{x}<br>feat2=%{y}<br>target=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.059188425297189665,-2.8774226651402866,-0.03936926917489769,1.7656123816017673,0.6581880846423186,0.8547147964165915,-1.0597172721045474,-0.8251940944552822,0.3229779539647967,0.48731485724246554,-0.437398644649179,0.2218390352386404,0.3368704439473176,-0.09021629471879893,-0.21475391990805542,-1.3665789433046696,0.234285827021381,0.9341078434725953,1.148200701545873,-0.6024594416987342,0.30214187992415853,0.13465257392093774,-1.2301887741297735,0.02363316168127733,0.4463323778700458,-0.838641803575626,2.1789526049744157,-0.9485330492876478,-1.3184358096707238,-0.26427996182377783,-0.6514198681046239,0.647174082451123,0.01884706982161754,-0.8597176967694854,-0.4722074463238236,0.2535078637970811,-0.034392456393707665,0.0860073002589315,0.18863447174440942,-0.6503342749455817,-0.11814452030985372,-0.6274185244218139,-0.5387197708014494,1.4159204238348881,1.1710962945146826,0.3142341829166473,0.10653700578986429,0.9016743063923514,1.514249806063117,-1.6006306087512168,-0.07020317217219083,-0.815530330059005,-0.33258567144212153,0.08729701390214746,0.6681716263117294,0.5037158199535633,-0.31016571087381595,-1.5501938129534543,0.28755545427250084,-0.2466967335490956,0.5882204556012576,-0.8731488378408899,-1.4858282972912433,-1.5788771165879707,0.2565541530545515,-1.2106748229085
#        [-2.23026301e-01, -5.15421205e+01],
#        [-5.53823862e+01, -6.26202458e+01],
#        [-6.01363906e+01, -8.70080767e+01],
#        [-1.30807068e+02, -3.02203933e+01],
#        [-7.92331582e+01, -8.07787472e+01],
#        [-2.08326032e+02, -1.79720424e+02],
#        [-6.87202525e+01, -4.34570306e+01],
#        [-1.53767250e+02, -8.69178997e+01],
#        [-1.35581672e+02, -1.32018453e+02],
#        [-4.66813809e+01, -3.90060097e+01],
#        [ 1.61280421e+01,  8.31538170e+00],
#        [ 1.79159737e+02,  1.08157449e+02],
#        [ 7.60640508e+01,  1.39411386e+02],
#        [-6.12388571e+01, -1.63620833e+01],
#        [-1.99991057e+02, -1.11960378e+02],
#        [-9.69213816e+00,  5.89870378e+01],
#        [-1.00710274e+02, -1.01107521e+02],
#        [ 2.92230781e+01,  8.89707607e+01],
#        [ 9.12509897e+01,  1.15854835e+02],
#        [ 1.30081338e+02,  1.58539220e+02]])

# %% [markdown]
# ### Model parameters

# %%
print('Coeffecients:',np.round(lr.coef_,2))
print('Intercept:',np.round(lr.intercept_,2))
# Out:
# Coeffecients: [51.51 78.76]
# Intercept: 2.93

# %% [markdown]
# ## Model Validation

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse  = np.sqrt(mse)
r2 = r2_score(y_test,y_pred)

# %%
print("Mean Absolute error",mae)
print("Mean Square error",mse)
print("Root Mean Squared error",rmse)
print("R2 score",r2)
# Out:
# Mean Absolute error 40.03239929164605
# Mean Square error 2453.1961629587067
# Root Mean Squared error 49.52975028161062
# R2 score 0.8183379384459435

# %% [markdown]
# # Build Own Multiple Regression Model from scratch

# %%
class MyMultipleRegressor:
    
    def __init__(self):
        self.coef = None
        self.intercept = None
        
    def fit(self, X,y):
        X_T = np.transpose(X)
        self.coef = np.linalg.solve(np.dot(X_T,X),np.dot(X_T,y))
        self.intercept = np.mean(y) - np.dot(np.mean(X,axis = 0),self.coef)
           
    def predict(self,X):
        y_pred = np.dot(X,self.coef) + self.intercept
        return y_pred

# %%
model = MyMultipleRegressor()

# %%
X_train.shape
# Out:
# (70, 2)

# %%
model.fit(X_train,y_train)

# %%
print(model.coef)
print(model.intercept)
# Out:
# [51.45476841 78.79501114]
# 2.925548022215872

# %%
y_pred2 = model.predict(X_test)

# %%
mae = mean_absolute_error(y_test,y_pred2)
mse = mean_squared_error(y_test,y_pred2)
rmse  = np.sqrt(mse)
r2 = r2_score(y_test,y_pred2)

# %%
print("Mean Absolute error",mae)
print("Mean Square error",mse)
print("Root Mean Squared error",rmse)
print("R2 score",r2)
# Out:
# Mean Absolute error 40.021785352405864
# Mean Square error 2452.866519134312
# Root Mean Squared error 49.526422434235165
# R2 score 0.8183623489588989
